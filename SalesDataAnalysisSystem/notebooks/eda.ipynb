# %%
import pandas as pd

# %%
#Step 5
path=r"../dataset/Automobiles_sales_dataset.xlsx"

# %%
sales=pd.read_excel(path,sheet_name="sales_dataset")

# %%
sales.head(5)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#              ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0       2/24/2003 0:00  Shipped       1         2     2003  ...
# 1  2003-07-05 00:00:00  Shipped       2         5     2003  ...
# 2  2003-01-07 00:00:00  Shipped       3         7     2003  ...
# 3       8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  2003-10-10 00:00:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
sales.isnull().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
sales.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   str
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   str
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   str
#  13  CUSTOMERNAME      2823 non-null   str
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   str
#  16  ADDRESSLINE2      302 non-null    str
# ...

# %%
sales.shape
# Out:
# (2823, 25)

# %%
print(sales.isnull().sum().sum()/sales.shape[0]*100,"%")
# Out:
# 182.6780021253985 %

# %%
sales.shape
# Out:
# (2823, 25)

# %%
sales.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='str')

# %%
for col in sales.columns:
    print(col)
# Out:
# ORDERNUMBER
# QUANTITYORDERED
# PRICEEACH
# ORDERLINENUMBER
# SALES
# ORDERDATE
# STATUS
# QTR_ID
# MONTH_ID
# YEAR_ID
# PRODUCTLINE
# MSRP
# PRODUCTCODE
# CUSTOMERNAME
# PHONE
# ADDRESSLINE1
# ADDRESSLINE2
# CITY
# STATE
# POSTALCODE
# COUNTRY
# TERRITORY
# CONTACTLASTNAME
# CONTACTFIRSTNAME
# DEALSIZE

# %%
sales['ADDRESSLINE2'].isnull().sum()
# Out:
# np.int64(2521)

# %%
sales.describe
# Out:
# <bound method NDFrame.describe of       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#                 ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
for col in sales.columns:
    if sales[col].isnull().sum()>0:
        print(col,'\t',sales[col].isnull().sum(),'\t',sales[col].dtype)
# Out:
# ADDRESSLINE2 	 2521 	 str
# STATE 	 1486 	 str
# POSTALCODE 	 76 	 object
# TERRITORY 	 1074 	 str

# %%
sales['ADDRESSLINE2'].mode()[0]
# Out:
# 'Level 3'

# %%
sales['ADDRESSLINE2'].value_counts()
# Out:
# ADDRESSLINE2
# Level 3        55
# Suite 400      48
# Level 6        46
# Level 15       46
# 2nd Floor      36
# Suite 101      25
# Suite 750      20
# Floor No. 4    16
# Suite 200      10
# Name: count, dtype: int64

# %%
for col in sales.select_dtypes(include="str").columns:
    print(col,'\t',sales[col].isnull().sum(),'\t Replaced By:',sales[col].mode()[0])
    sales[col]=sales[col].fillna(sales[col].mode()[0])
# Out:
# STATUS 	 0 	 Replaced By: Shipped
# PRODUCTLINE 	 0 	 Replaced By: Classic Cars
# PRODUCTCODE 	 0 	 Replaced By: S18_3232
# CUSTOMERNAME 	 0 	 Replaced By: Euro Shopping Channel
# ADDRESSLINE1 	 0 	 Replaced By: C/ Moralzarzal, 86
# ADDRESSLINE2 	 2521 	 Replaced By: Level 3
# CITY 	 0 	 Replaced By: Madrid
# STATE 	 1486 	 Replaced By: CA
# COUNTRY 	 0 	 Replaced By: USA
# TERRITORY 	 1074 	 Replaced By: EMEA
# CONTACTLASTNAME 	 0 	 Replaced By: Freyre
# CONTACTFIRSTNAME 	 0 	 Replaced By: Diego
# DEALSIZE 	 0 	 Replaced By: Medium

# %%
sales.isnull().sum()
# Out:
# ORDERNUMBER          0
# QUANTITYORDERED      0
# PRICEEACH            0
# ORDERLINENUMBER      0
# SALES                0
# ORDERDATE            0
# STATUS               0
# QTR_ID               0
# MONTH_ID             0
# YEAR_ID              0
# PRODUCTLINE          0
# MSRP                 0
# PRODUCTCODE          0
# CUSTOMERNAME         0
# PHONE                0
# ADDRESSLINE1         0
# ADDRESSLINE2         0
# CITY                 0
# STATE                0
# POSTALCODE          76
# COUNTRY              0
# TERRITORY            0
# CONTACTLASTNAME      0
# CONTACTFIRSTNAME     0
# DEALSIZE             0
# dtype: int64

# %%
sales.head(5)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#              ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0       2/24/2003 0:00  Shipped       1         2     2003  ...
# 1  2003-07-05 00:00:00  Shipped       2         5     2003  ...
# 2  2003-01-07 00:00:00  Shipped       3         7     2003  ...
# 3       8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  2003-10-10 00:00:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue       Level 3            NYC    NY
# ...

# %%
sales['ORDERDATE']=pd.to_datetime(sales['ORDERDATE'])

# %%
sales.head(20)
# Out:
#     ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0         10107               30      95.70                2  2871.00
# 1         10121               34      81.35                5  2765.90
# 2         10134               41      94.74                2  3884.34
# 3         10145               45      83.26                6  3746.70
# 4         10159               49     100.00               14  5205.27
# 5         10168               36      96.66                1  3479.76
# 6         10180               29      86.13                9  2497.77
# 7         10188               48     100.00                1  5512.32
# 8         10201               22      98.57                2  2168.54
# 9         10211               41     100.00               14  4708.44
# 10        10223               37     100.00                1  3965.66
# 11        10237               23     100.00                7  2333.12
# ...

# %%
sales.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='str')

# %%
#Total Sales
print(sales['SALES'].sum())
# Out:
# 10032628.85

# %%
#TOTAL PROFIT
print((sales['QUANTITYORDERED']*sales['PRICEEACH'])-(sales['QUANTITYORDERED']*sales['MSRP']))
# Out:
# 0         21.00
# 1       -464.10
# 2        -10.66
# 3       -528.30
# 4        245.00
#          ...
# 2818     920.00
# 2819    1334.00
# 2820    1978.00
# 2821     280.16
# 2822     541.44
# Length: 2823, dtype: float64

# %%
#Top Selling Products
print(sales.groupby('PRODUCTLINE')['SALES'].sum().sort_values(ascending=False))
# Out:
# PRODUCTLINE
# Classic Cars        3919615.66
# Vintage Cars        1903150.84
# Motorcycles         1166388.34
# Trucks and Buses    1127789.84
# Planes               975003.57
# Ships                714437.13
# Trains               226243.47
# Name: SALES, dtype: float64

# %%
#Region wise sales
print(sales.groupby('COUNTRY')['SALES'].sum())
# Out:
# COUNTRY
# Australia       630623.10
# Austria         202062.53
# Belgium         108412.62
# Canada          224078.56
# Denmark         245637.15
# Finland         329581.91
# France         1110916.52
# Germany         220472.09
# Ireland          57756.43
# Italy           374674.31
# Japan           188167.81
# Norway          307463.70
# Philippines      94015.73
# Singapore       288488.41
# Spain          1215686.92
# Sweden          210014.21
# Switzerland     117713.56
# UK              478880.46
# USA            3627982.83
# Name: SALES, dtype: float64

# %%
#Monthly Sales Analysis
sales['MONTH_ID']=sales['ORDERDATE'].dt.month
print(sales.groupby('MONTH_ID')['SALES'].sum())
# Out:
# MONTH_ID
# 1      962396.71
# 2     1005383.81
# 3      797370.26
# 4      744538.06
# 5      862597.77
# 6      684918.75
# 7      490103.29
# 8      723921.76
# 9      561245.65
# 10    1272067.31
# 11    1489274.30
# 12     438811.18
# Name: SALES, dtype: float64

# %%
sales.shape
# Out:
# (2823, 25)

# %%
#Best 
print(sales.groupby('CUSTOMERNAME')['SALES'].sum().sort_values(ascending=False).head(5))
# Out:
# CUSTOMERNAME
# Euro Shopping Channel           912294.11
# Mini Gifts Distributors Ltd.    654858.06
# Australian Collectors, Co.      200995.41
# Muscle Machine Inc              197736.94
# La Rochelle Gifts               180124.90
# Name: SALES, dtype: float64

# %%
sales.info
# Out:
# <bound method DataFrame.info of       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#       ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
sales=sales.rename(columns={'ORDER_DATE':'ORDERDATE','Country':'COUNTRY'})

# %%
filtered_sales=sales.copy()

# %%
filtered_sales
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#       ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
sales.head(2)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER   SALES  \
# 0        10107               30      95.70                2  2871.0
# 1        10121               34      81.35                5  2765.9
#
#    ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0 2003-02-24  Shipped       1         2     2003  ...
# 1 2003-07-05  Shipped       2         7     2003  ...
#
#               ADDRESSLINE1  ADDRESSLINE2   CITY STATE POSTALCODE COUNTRY  \
# 0  897 Long Airport Avenue       Level 3    NYC    NY      10022     USA
# 1       59 rue de l'Abbaye       Level 3  Reims    CA      51100  France
#
#   TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0      EMEA              Yu             Kwai    Small
# 1      EMEA         Henriot             Paul    Small
#
# [2 rows x 25 columns]

# %%
print(sales.columns.tolist())
# Out:
# ['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER', 'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID', 'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE', 'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE', 'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME', 'DEALSIZE']

# %%
for col in sales.columns:
    print(col[3],col,sales[col].dtype)
# Out:
# E ORDERNUMBER int64
# N QUANTITYORDERED int64
# C PRICEEACH float64
# E ORDERLINENUMBER int64
# E SALES float64
# E ORDERDATE datetime64[us]
# T STATUS str
# _ QTR_ID int64
# T MONTH_ID int32
# R YEAR_ID int64
# D PRODUCTLINE str
# P MSRP int64
# D PRODUCTCODE str
# T CUSTOMERNAME str
# N PHONE object
# R ADDRESSLINE1 str
# R ADDRESSLINE2 str
# Y CITY str
# T STATE str
# T POSTALCODE object
# N COUNTRY str
# R TERRITORY str
# T CONTACTLASTNAME str
# T CONTACTFIRSTNAME str
# L DEALSIZE str

# %%
sales.head(2)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER   SALES  \
# 0        10107               30      95.70                2  2871.0
# 1        10121               34      81.35                5  2765.9
#
#    ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0 2003-02-24  Shipped       1         2     2003  ...
# 1 2003-07-05  Shipped       2         7     2003  ...
#
#               ADDRESSLINE1  ADDRESSLINE2   CITY STATE POSTALCODE COUNTRY  \
# 0  897 Long Airport Avenue       Level 3    NYC    NY      10022     USA
# 1       59 rue de l'Abbaye       Level 3  Reims    CA      51100  France
#
#   TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0      EMEA              Yu             Kwai    Small
# 1      EMEA         Henriot             Paul    Small
#
# [2 rows x 25 columns]

# %%
sales.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='str')

# %%
print(sales.columns.tolist())
# Out:
# ['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER', 'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID', 'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE', 'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE', 'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME', 'DEALSIZE']

# %%
for col in sales.columns:
    print(repr(col))
# Out:
# 'ORDERNUMBER'
# 'QUANTITYORDERED'
# 'PRICEEACH'
# 'ORDERLINENUMBER'
# 'SALES'
# 'ORDERDATE'
# 'STATUS'
# 'QTR_ID'
# 'MONTH_ID'
# 'YEAR_ID'
# 'PRODUCTLINE'
# 'MSRP'
# 'PRODUCTCODE'
# 'CUSTOMERNAME'
# 'PHONE'
# 'ADDRESSLINE1'
# 'ADDRESSLINE2'
# 'CITY'
# 'STATE'
# 'POSTALCODE'
# 'COUNTRY'
# 'TERRITORY'
# 'CONTACTLASTNAME'
# 'CONTACTFIRSTNAME'
# 'DEALSIZE'

# %%
filtered_sales.head(2)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER   SALES  \
# 0        10107               30      95.70                2  2871.0
# 1        10121               34      81.35                5  2765.9
#
#    ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0 2003-02-24  Shipped       1         2     2003  ...
# 1 2003-07-05  Shipped       2         7     2003  ...
#
#               ADDRESSLINE1  ADDRESSLINE2   CITY STATE POSTALCODE COUNTRY  \
# 0  897 Long Airport Avenue       Level 3    NYC    NY      10022     USA
# 1       59 rue de l'Abbaye       Level 3  Reims    CA      51100  France
#
#   TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0      EMEA              Yu             Kwai    Small
# 1      EMEA         Henriot             Paul    Small
#
# [2 rows x 25 columns]

# %%
((filtered_sales['ORDERNUMBER']).unique())
# Out:
# array([10107, 10121, 10134, 10145, 10159, 10168, 10180, 10188, 10201,
#        10211, 10223, 10237, 10251, 10263, 10275, 10285, 10299, 10309,
#        10318, 10329, 10341, 10361, 10375, 10388, 10403, 10417, 10103,
#        10112, 10126, 10140, 10150, 10163, 10174, 10183, 10194, 10206,
#        10215, 10228, 10245, 10258, 10270, 10280, 10291, 10304, 10312,
#        10322, 10333, 10347, 10357, 10369, 10381, 10391, 10411, 10424,
#        10120, 10210, 10236, 10298, 10308, 10339, 10374, 10402, 10362,
#        10105, 10119, 10129, 10143, 10155, 10167, 10178, 10186, 10197,
#        10209, 10222, 10248, 10261, 10273, 10283, 10295, 10307, 10316,
#        10325, 10337, 10350, 10359, 10373, 10384, 10395, 10400, 10414,
#        10114, 10164, 10175, 10207, 10217, 10229, 10259, 10281, 10305,
#        10313, 10334, 10370, 10425, 10108, 10122, 10135, 10147, 10169,
#        10181, 10191, 10203, 10225, 10238, 10253, 10266, 10276, 10287,
# ...

# %%
filtered_sales.shape[0]
# Out:
# 2823

# %%
round(float(filtered_sales['SALES'].sum()))
# Out:
# 10032629

# %%
(filtered_sales.groupby('COUNTRY')['SALES'].sum())
# Out:
# COUNTRY
# Australia       630623.10
# Austria         202062.53
# Belgium         108412.62
# Canada          224078.56
# Denmark         245637.15
# Finland         329581.91
# France         1110916.52
# Germany         220472.09
# Ireland          57756.43
# Italy           374674.31
# Japan           188167.81
# Norway          307463.70
# Philippines      94015.73
# Singapore       288488.41
# Spain          1215686.92
# Sweden          210014.21
# Switzerland     117713.56
# UK              478880.46
# USA            3627982.83
# Name: SALES, dtype: float64

# %%
filtered_sales.groupby('COUNTRY', as_index=False)['SALES'].sum().sort_values('SALES', ascending=False).head(1)
# Out:
#    COUNTRY       SALES
# 18     USA  3627982.83

# %%
(filtered_sales.groupby('COUNTRY', as_index=False)['PRODUCTLINE'].sum().sort_values('PRODUCTLINE', ascending=False).head(1))
# Out:
#    COUNTRY                                        PRODUCTLINE
# 18     USA  MotorcyclesMotorcyclesMotorcyclesMotorcyclesMo...

# %%
filtered_sales['PRODUCTLINE'].max()
# Out:
# 'Vintage Cars'

# %%
filtered_sales.groupby('MONTH_ID')['SALES'].sum()
# Out:
# MONTH_ID
# 1      962396.71
# 2     1005383.81
# 3      797370.26
# 4      744538.06
# 5      862597.77
# 6      684918.75
# 7      490103.29
# 8      723921.76
# 9      561245.65
# 10    1272067.31
# 11    1489274.30
# 12     438811.18
# Name: SALES, dtype: float64

# %%
round(float(filtered_sales.groupby('COUNTRY')['SALES'].sum().max()))
# Out:
# 3627983

# %%
filtered_sales.groupby('COUNTRY')['SALES'].sum().reset_index()
# Out:
#         COUNTRY       SALES
# 0     Australia   630623.10
# 1       Austria   202062.53
# 2       Belgium   108412.62
# 3        Canada   224078.56
# 4       Denmark   245637.15
# 5       Finland   329581.91
# 6        France  1110916.52
# 7       Germany   220472.09
# 8       Ireland    57756.43
# 9         Italy   374674.31
# 10        Japan   188167.81
# 11       Norway   307463.70
# 12  Philippines    94015.73
# 13    Singapore   288488.41
# 14        Spain  1215686.92
# 15       Sweden   210014.21
# 16  Switzerland   117713.56
# 17           UK   478880.46
# 18          USA  3627982.83

# %%
filtered_sales.groupby('MONTH_ID')['SALES'].sum()
# Out:
# MONTH_ID
# 1      962396.71
# 2     1005383.81
# 3      797370.26
# 4      744538.06
# 5      862597.77
# 6      684918.75
# 7      490103.29
# 8      723921.76
# 9      561245.65
# 10    1272067.31
# 11    1489274.30
# 12     438811.18
# Name: SALES, dtype: float64

# %%
sales.head(10)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
# 5        10168               36      96.66                1  3479.76
# 6        10180               29      86.13                9  2497.77
# 7        10188               48     100.00                1  5512.32
# 8        10201               22      98.57                2  2168.54
# 9        10211               41     100.00               14  4708.44
#
#    ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0 2003-02-24  Shipped       1         2     2003  ...
# 1 2003-07-05  Shipped       2         7     2003  ...
# ...
